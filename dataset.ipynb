# %% [markdown]
# ### Open and initial analysis of the dataset

# %%
# Library for data processing and analysis
import pandas as pd

# Library for working with data arrays
import numpy as np

# Charting Library
import matplotlib.pyplot as plt

# Charting Library
import seaborn as sns

# %%
# Load dataset
cards_data = pd.read_csv(path_data, index_col='id')
cards_data.head()
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# id
# 0  -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2  -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3  -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4  -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# id                                ...
# 0  -0.130006  0.727159  0.637735  ... -0.110552  0.217606 -0.134794  0.165959
# 1  -0.133118  0.347452  0.529808  ... -0.194936 -0.605761  0.079469 -0.577395
# 2  -0.095576 -0.261297  0.690708  ... -0.005020  0.702906  0.945045 -1.154666
# 3  -0.065130 -0.205698  0.575231  ... -0.146927 -0.038212 -0.214048 -1.893131
# 4  -0.212660  1.049921  0.968046  ... -0.106984  0.729727 -0.161666  0.312561
#
# ...

# %%
cards_data.shape
# Out:
# (568630, 30)

# %% [markdown]
# We have:
# * strings - 568630
# * columns - 30

# %%
# Let's look at None in the dataset

fig, ax = plt.subplots(figsize=(20,12)) # Create an area for the chart
sns_heatmap = sns.heatmap(cards_data.isnull(), yticklabels=False, cbar=False, cmap='viridis') # Visualize the passes
plt.show() # Displaying the graph

# %% [markdown]
# As we can see, we have no passes

# %%
# Checking the balance of data

plt.figure(figsize=(10,8)) # Create an area for the chart

plt.title('Проверка сбалансированности данных', fontsize=16) # Name of gragh

sns.countplot(x='Class', data=cards_data) # Plotting a countplot
# Out:
# <Axes: title={'center': 'Проверка сбалансированности данных'}, xlabel='Class', ylabel='count'>

# %% [markdown]
# We have balanced data
